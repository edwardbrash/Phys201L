# %% [markdown]
# # PHYS 201L GitHub and Colab check
#
# This short exercise confirms that your team can open a notebook from its GitHub fork, run it in Colab, and save the result back to GitHub. Do not begin until you are viewing the notebook from your **team's fork**.

# %% [markdown]
# ## Team information
#
# Replace the prompts below with your information.
#
# **Team name:** YOUR TEAM NAME
# **Team members:** TEAM MEMBER NAMES
# **Repository manager:** REPOSITORY MANAGER NAME

# %%
team_name = "Replace this text with your team name"
print(f"GitHub and Colab are ready for {team_name}!")

# %% [markdown]
# ## Save test
#
# 1. Run the code cell above.
# 2. In Colab, select **File → Save a copy in GitHub**.
# 3. Choose your team's fork and save to `Start_Here.ipynb`.
# 4. Use the commit message `Complete Colab save test`.
# 5. Return to GitHub and verify that your names, team name, code output, and commit appear in the team's fork.
